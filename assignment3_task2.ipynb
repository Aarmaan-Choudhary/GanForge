# %%
import os
import torch
from PIL import Image
from torchvision import models, transforms

# Define the path to the Cat directory using the current working directory
cat_folder = os.path.join(os.getcwd(), 'PetImages', 'Cat')

# Print the path to verify it's correct
print(f"Looking for images in: {cat_folder}")

# Get list of image files in the Cat directory
image_files_cat = [f for f in os.listdir(cat_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
print(f"Found {len(image_files_cat)} images")

# Load the pre-trained ResNet model
weights = models.ResNet18_Weights.IMAGENET1K_V1
model = models.resnet18(weights=weights)
model.eval()  # Set the model to evaluation mode

# Define the image transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Process each image
for image_file in image_files_cat:
    try:
        # Construct the full path to the image
        image_path = os.path.join(cat_folder, image_file)
        
        # Open and transform the image
        image = Image.open(image_path)
        input_tensor = transform(image).unsqueeze(0)

        # Check if the image is RGB (3 channels)
        if input_tensor.size()[1] == 3:
            with torch.no_grad():
                output_tensor = model(input_tensor)
            prediction = weights.meta["categories"][output_tensor.argmax().item()]
            print(f'{image_file} predicted as {prediction}')
        else:
            print(f'{image_file} is a black and white image')
            
    except Exception as e:
        print(f'Error processing {image_file}: {str(e)}')

dog_folder=os.path.join(os.getcwd(),'PetImages','Dog')
image_files_dog = [f for f in os.listdir(dog_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
print(f"Found {len(image_files_dog)} images")

for image_file in image_files_dog:
    image_path=os.path.join(dog_folder,image_file)

    image=Image.open(image_path)
    input_tensor=transform(image).unsqueeze(0)

    if input_tensor.size()[1]==3:
        with torch.no_grad():
            output_tensor=model(input_tensor)
        prediction=weights.meta["categories"][output_tensor.argmax().item()]
        print(f'{image_file} predicted as {prediction}')
    else:
        print(f'{image_file} is a black and white image')
# Out:
# Looking for images in: c:\Users\Aarmaan Choudhary\Desktop\Assignment3\PetImages\Cat
# Found 12500 images
# 0.jpg predicted as red fox
# 1.jpg predicted as tiger cat
# 10.jpg predicted as Egyptian cat
# 100.jpg predicted as Egyptian cat
# 1000.jpg predicted as window screen
# 10000.jpg predicted as Egyptian cat
# 10001.jpg predicted as tabby
# 10002.jpg predicted as plastic bag
# 10003.jpg predicted as Egyptian cat
# 10004.jpg predicted as Egyptian cat
# 10005.jpg predicted as Siamese cat
# 10006.jpg predicted as tabby
# 10007.jpg predicted as Egyptian cat
# 10008.jpg predicted as paper towel
# 10009.jpg predicted as Persian cat
# 1001.jpg predicted as bassinet
# 10010.jpg predicted as schipperke
# 10011.jpg predicted as Persian cat
# 10012.jpg predicted as tabby
# 10013.jpg predicted as Persian cat
# 10014.jpg predicted as schipperke
# 10015.jpg predicted as paper towel
# 10016.jpg predicted as tabby
# 10017.jpg predicted as cradle
# 10018.jpg predicted as bathtub
# 10019.jpg predicted as tub
# 1002.jpg predicted as Egyptian cat
# 10020.jpg predicted as tiger cat
# 10021.jpg predicted as tabby
# 10022.jpg predicted as Siamese cat
# 10023.jpg predicted as Egyptian cat
# 10024.jpg predicted as Bernese mountain dog
# 10025.jpg predicted as Pembroke
# 10026.jpg predicted as bassinet
# 10027.jpg predicted as schipperke
# 10028.jpg predicted as Egyptian cat
# 10029.jpg predicted as wall clock
# 1003.jpg predicted as Persian cat
# 10030.jpg predicted as Persian cat
# 10031.jpg predicted as Egyptian cat
# 10032.jpg predicted as Egyptian cat
# 10033.jpg predicted as plastic bag
# 10034.jpg predicted as Egyptian cat
# 10035.jpg predicted as tabby
# 10036.jpg predicted as bathtub
# 10037.jpg predicted as mosquito net
# 10038.jpg predicted as Egyptian cat
# 10039.jpg predicted as Egyptian cat
# 1004.jpg predicted as quilt
# 10040.jpg predicted as Angora
# 10041.jpg predicted as Egyptian cat
# 10042.jpg predicted as Egyptian cat
# 10043.jpg predicted as bonnet
# 10044.jpg predicted as bath towel
# 10045.jpg predicted as tabby
# 10046.jpg predicted as tiger cat
# 10047.jpg predicted as paper towel
# 10048.jpg predicted as plunger
# 10049.jpg predicted as Egyptian cat
# 1005.jpg predicted as tiger cat
# 10050.jpg predicted as grey fox
# 10051.jpg predicted as Siamese cat
# 10052.jpg predicted as Arctic fox
# 10053.jpg predicted as tabby
# 10054.jpg predicted as Egyptian cat
# 10055.jpg predicted as Persian cat
# 10056.jpg predicted as Persian cat
# 10057.jpg predicted as Egyptian cat
# 10058.jpg predicted as Persian cat
# 10059.jpg predicted as Persian cat
# 1006.jpg predicted as paper towel
# 10060.jpg predicted as Egyptian cat
# 10061.jpg predicted as Siamese cat
# 10062.jpg predicted as Egyptian cat
# 10063.jpg predicted as tiger cat
# 10064.jpg predicted as tabby
# 10065.jpg predicted as shower curtain
# 10066.jpg predicted as Egyptian cat
# 10067.jpg predicted as Persian cat
# 10068.jpg predicted as toilet tissue
# 10069.jpg predicted as paper towel
# 1007.jpg predicted as Egyptian cat
# 10070.jpg predicted as plastic bag
# 10071.jpg predicted as bassinet
# 10072.jpg predicted as Egyptian cat
# 10073.jpg predicted as Persian cat
# 10074.jpg predicted as tub
# 10075.jpg predicted as Egyptian cat
# 10076.jpg predicted as paper towel
# 10077.jpg predicted as washbasin
# 10078.jpg predicted as Persian cat
# 10079.jpg predicted as bassinet
# 1008.jpg predicted as shower curtain
# 10080.jpg predicted as Egyptian cat
# 10081.jpg predicted as bonnet
# 10082.jpg predicted as Egyptian cat
# 10083.jpg predicted as Egyptian cat
# 10084.jpg predicted as tub
# 10085.jpg predicted as tabby
# 10086.jpg predicted as Egyptian cat
# 10087.jpg predicted as Persian cat
# 10088.jpg predicted as tiger cat
# 10089.jpg predicted as Siberian husky
# 1009.jpg predicted as plastic bag
# 10090.jpg predicted as mosquito net
# 10091.jpg predicted as plastic bag
# 10092.jpg predicted as Angora
# 10093.jpg predicted as lynx
# 10094.jpg predicted as Persian cat
# 10095.jpg predicted as Egyptian cat
# 10096.jpg predicted as Egyptian cat
# 10097.jpg predicted as Egyptian cat
# 10098.jpg predicted as shower cap
# 10099.jpg predicted as tub
# 101.jpg predicted as Persian cat
# 1010.jpg predicted as Persian cat
# 10100.jpg predicted as Egyptian cat
# 10101.jpg predicted as Egyptian cat
# 10102.jpg predicted as china cabinet
# 10103.jpg predicted as tabby
# 10104.jpg predicted as Egyptian cat
# 10105.jpg predicted as Persian cat
# 10106.jpg predicted as miniature pinscher
# 10107.jpg predicted as plastic bag
# 10108.jpg predicted as toilet tissue
# 10109.jpg predicted as paper towel
# 1011.jpg predicted as Persian cat
# 10110.jpg predicted as Egyptian cat
# 10111.jpg predicted as lynx
# 10112.jpg predicted as Persian cat
# 10113.jpg predicted as Angora
# 10114.jpg predicted as Egyptian cat
# 10115.jpg predicted as Egyptian cat
# 10116.jpg predicted as Siberian husky
# 10117.jpg predicted as Egyptian cat
# 10118.jpg predicted as paper towel
# 10119.jpg predicted as quilt
# 1012.jpg predicted as window screen
# 10120.jpg predicted as mosquito net
# 10121.jpg predicted as bassinet
# 10122.jpg predicted as Persian cat
# 10123.jpg predicted as Egyptian cat
# 10124.jpg predicted as Persian cat
# 10125.jpg is a black and white image
# 10126.jpg predicted as shower curtain
# 10127.jpg predicted as killer whale
# 10128.jpg predicted as Egyptian cat
# 10129.jpg predicted as French bulldog
# 1013.jpg predicted as Egyptian cat
# 10130.jpg predicted as Arctic fox
# 10131.jpg predicted as Egyptian cat
# 10132.jpg predicted as Samoyed
# 10133.jpg predicted as tub
# 10134.jpg predicted as washbasin
# 10135.jpg predicted as Egyptian cat
# 10136.jpg predicted as Persian cat
# 10137.jpg predicted as Siamese cat
# 10138.jpg predicted as Egyptian cat
# 10139.jpg predicted as red fox
# 1014.jpg predicted as Egyptian cat
# 10140.jpg predicted as Egyptian cat
# 10141.jpg predicted as toilet seat
# 10142.jpg predicted as dishwasher
# 10143.jpg predicted as Egyptian cat
# 10144.jpg predicted as Siamese cat
# 10145.jpg predicted as ice bear
# 10146.jpg predicted as Egyptian cat
# 10147.jpg predicted as washbasin
# 10148.jpg predicted as bassinet
# 10149.jpg predicted as paper towel
# 1015.jpg predicted as Egyptian cat
# 10150.jpg predicted as toilet seat
# 10151.jpg predicted as toilet tissue
# 10152.jpg predicted as Egyptian cat
# 10153.jpg predicted as bassinet
# 10154.jpg predicted as Persian cat
# 10155.jpg predicted as Egyptian cat
# 10156.jpg predicted as Persian cat
# 10157.jpg predicted as tub
# 10158.jpg predicted as Egyptian cat
# 10159.jpg predicted as Egyptian cat
# 1016.jpg predicted as Egyptian cat
# 10160.jpg predicted as paper towel
# 10161.jpg predicted as Persian cat
# 10162.jpg predicted as tabby
# 10163.jpg predicted as shower curtain
# 10164.jpg predicted as tabby
# 10165.jpg predicted as tub
# 10166.jpg predicted as great white shark
# 10167.jpg predicted as cougar
# 10168.jpg predicted as tiger cat
# 10169.jpg predicted as mosquito net
# 1017.jpg predicted as Persian cat
# 10170.jpg predicted as Egyptian cat
# 10171.jpg predicted as Egyptian cat
# 10172.jpg predicted as tabby
# 10173.jpg predicted as tiger cat
# 10174.jpg predicted as Egyptian cat
# 10175.jpg predicted as bassinet
# 10176.jpg predicted as bassinet
# 10177.jpg predicted as Egyptian cat
# 10178.jpg predicted as tiger cat
# 10179.jpg predicted as Egyptian cat
# 1018.jpg predicted as bassinet
# 10180.jpg predicted as Egyptian cat
# 10181.jpg predicted as paper towel
# 10182.jpg predicted as paper towel
# 10183.jpg predicted as paper towel
# 10184.jpg predicted as Arctic fox
# 10185.jpg predicted as shower curtain
# 10186.jpg predicted as Persian cat
# 10187.jpg predicted as tabby
# 10188.jpg predicted as bucket
# 10189.jpg predicted as Egyptian cat
# 1019.jpg predicted as tabby
# 10190.jpg predicted as Samoyed
# 10191.jpg predicted as tiger cat
# 10192.jpg predicted as plastic bag
# 10193.jpg predicted as tiger cat
# 10194.jpg predicted as lynx
# 10195.jpg predicted as Egyptian cat
# 10196.jpg predicted as conch
# 10197.jpg predicted as Siamese cat
# 10198.jpg predicted as Egyptian cat
# 10199.jpg predicted as Egyptian cat
# 102.jpg predicted as Egyptian cat
# 1020.jpg predicted as Egyptian cat
# 10200.jpg predicted as Egyptian cat
# 10201.jpg predicted as plastic bag
# 10202.jpg predicted as bonnet
# 10203.jpg predicted as washbasin
# 10204.jpg predicted as Egyptian cat
# 10205.jpg predicted as paper towel
# 10206.jpg predicted as bassinet
# 10207.jpg predicted as bassinet
# 10208.jpg predicted as tabby
# 10209.jpg predicted as face powder
# 1021.jpg predicted as Egyptian cat
# 10210.jpg predicted as toilet seat
# 10211.jpg predicted as tub
# 10212.jpg predicted as Egyptian cat
# 10213.jpg predicted as plastic bag
# 10214.jpg predicted as tiger cat
# 10215.jpg predicted as bathtub
# 10216.jpg predicted as plastic bag
# 10217.jpg predicted as mousetrap
# 10218.jpg predicted as Egyptian cat
# 10219.jpg predicted as mosquito net
# 1022.jpg predicted as Persian cat
# 10220.jpg predicted as English springer
# 10221.jpg predicted as washbasin
# 10222.jpg predicted as Egyptian cat
# 10223.jpg predicted as shower cap
# 10224.jpg predicted as Egyptian cat
# 10225.jpg predicted as tiger cat
# 10226.jpg predicted as piggy bank
# 10227.jpg predicted as brassiere
# 10228.jpg predicted as lynx
# 10229.jpg predicted as Egyptian cat
# 1023.jpg predicted as tiger cat
# 10230.jpg predicted as thimble
# 10231.jpg predicted as Egyptian cat
# 10232.jpg predicted as Egyptian cat
# 10233.jpg predicted as Egyptian cat
# 10234.jpg predicted as Egyptian cat
# 10235.jpg predicted as Persian cat
# 10236.jpg predicted as plastic bag
# 10237.jpg predicted as bathtub
# 10238.jpg predicted as Egyptian cat
# 10239.jpg predicted as tub
# 1024.jpg predicted as tiger cat
# 10240.jpg predicted as Egyptian cat
# 10241.jpg predicted as plastic bag
# 10242.jpg predicted as Egyptian cat
# 10243.jpg predicted as basenji
# 10244.jpg predicted as tabby
# 10245.jpg predicted as Egyptian cat
# 10246.jpg predicted as Egyptian cat
# 10247.jpg predicted as Egyptian cat
# 10248.jpg predicted as missile
# 10249.jpg predicted as Egyptian cat
# 1025.jpg predicted as tabby
# 10250.jpg predicted as Egyptian cat
# 10251.jpg predicted as tabby
# 10252.jpg predicted as plastic bag
# 10253.jpg predicted as Egyptian cat
# 10254.jpg predicted as plastic bag
# 10255.jpg predicted as carton
# 10256.jpg predicted as shower curtain
# 10257.jpg predicted as bassinet
# 10258.jpg predicted as toy terrier
# 10259.jpg predicted as Egyptian cat
# 1026.jpg predicted as Egyptian cat
# 10260.jpg predicted as Eskimo dog
# 10261.jpg predicted as Persian cat
# 10262.jpg predicted as brassiere
# 10263.jpg predicted as miniature pinscher
# 10264.jpg predicted as lynx
# 10265.jpg predicted as mosquito net
# 10266.jpg predicted as flat-coated retriever
# 10267.jpg predicted as pitcher
# 10268.jpg predicted as Egyptian cat
# 10269.jpg predicted as Persian cat
# 1027.jpg predicted as Egyptian cat
# 10270.jpg predicted as toilet tissue
# 10271.jpg predicted as Eskimo dog
# 10272.jpg predicted as mosquito net
# 10273.jpg predicted as paper towel
# 10274.jpg predicted as lynx
# 10275.jpg predicted as Siamese cat
# 10276.jpg predicted as stingray
# 10277.jpg predicted as pedestal
# 10278.jpg predicted as Persian cat
# 10279.jpg predicted as tabby
# 1028.jpg predicted as Egyptian cat
# 10280.jpg predicted as Egyptian cat
# 10281.jpg predicted as Persian cat
# 10282.jpg predicted as paper towel
# 10283.jpg predicted as schipperke
# 10284.jpg predicted as Egyptian cat
# 10285.jpg predicted as Egyptian cat
# 10286.jpg predicted as Angora
# 10287.jpg predicted as Egyptian cat
# 10288.jpg predicted as Egyptian cat
# 10289.jpg predicted as Egyptian cat
# 1029.jpg predicted as shower curtain
# 10290.jpg predicted as miniature pinscher
# 10291.jpg predicted as Egyptian cat
# 10292.jpg predicted as Egyptian cat
# 10293.jpg predicted as Siamese cat
# 10294.jpg predicted as bassinet
# 10295.jpg predicted as Persian cat
# 10296.jpg predicted as bath towel
# 10297.jpg predicted as shower curtain
# 10298.jpg predicted as Egyptian cat
# 10299.jpg predicted as Egyptian cat
# 103.jpg predicted as Egyptian cat
# 1030.jpg predicted as toilet tissue
# 10300.jpg predicted as Persian cat
# 10301.jpg predicted as Arctic fox
# 10302.jpg predicted as washer
# 10303.jpg predicted as tabby
# 10304.jpg predicted as Egyptian cat
# 10305.jpg predicted as Persian cat
# 10306.jpg predicted as shower curtain
# 10307.jpg predicted as Persian cat
# 10308.jpg predicted as tiger cat
# 10309.jpg predicted as Egyptian cat
# 1031.jpg predicted as toilet tissue
# 10310.jpg predicted as lynx
# 10311.jpg predicted as Egyptian cat
# 10312.jpg predicted as paper towel
# 10313.jpg predicted as Egyptian cat
# 10314.jpg predicted as plastic bag
# 10315.jpg predicted as Egyptian cat
# 10316.jpg predicted as Egyptian cat
# 10317.jpg predicted as Egyptian cat
# 10318.jpg predicted as tiger cat
# 10319.jpg predicted as plastic bag
# 1032.jpg predicted as bathtub
# 10320.jpg predicted as Siamese cat
# 10321.jpg predicted as kit fox
# 10322.jpg predicted as Siberian husky
# 10323.jpg predicted as Egyptian cat
# 10324.jpg predicted as window screen
# 10325.jpg predicted as paper towel
# 10326.jpg predicted as mosquito net
# 10327.jpg predicted as plastic bag
# 10328.jpg predicted as mosquito net
# 10329.jpg predicted as Egyptian cat
# 1033.jpg predicted as tabby
# 10330.jpg predicted as Egyptian cat
# 10331.jpg predicted as toilet tissue
# 10332.jpg predicted as tiger cat
# 10333.jpg predicted as shower curtain
# 10334.jpg predicted as bathtub
# 10335.jpg predicted as Egyptian cat
# 10336.jpg predicted as toilet seat
# 10337.jpg predicted as Egyptian cat
# 10338.jpg predicted as shower curtain
# 10339.jpg predicted as mosquito net
# 1034.jpg predicted as Pembroke
# 10340.jpg predicted as bassinet
# 10341.jpg predicted as Persian cat
# 10342.jpg predicted as tabby
# 10343.jpg predicted as shower curtain
# 10344.jpg predicted as Persian cat
# 10345.jpg predicted as plastic bag
# 10346.jpg predicted as miniature pinscher
# 10347.jpg predicted as Egyptian cat
# 10348.jpg predicted as Egyptian cat
# 10349.jpg predicted as plastic bag
# 1035.jpg predicted as harp
# 10350.jpg predicted as Egyptian cat
# 10351.jpg predicted as Egyptian cat
# 10352.jpg predicted as tabby
# 10353.jpg predicted as plastic bag
# 10354.jpg predicted as Siamese cat
# 10355.jpg predicted as bathtub
# 10356.jpg predicted as cradle
# 10357.jpg predicted as plastic bag
# 10358.jpg predicted as Samoyed
# 10359.jpg predicted as Egyptian cat
# 1036.jpg predicted as mousetrap
# 10360.jpg predicted as hoopskirt
# 10361.jpg predicted as Egyptian cat
# 10362.jpg predicted as Angora
# 10363.jpg predicted as gown
# 10364.jpg predicted as Egyptian cat
# 10365.jpg predicted as plastic bag
# 10366.jpg predicted as tabby
# 10367.jpg predicted as Egyptian cat
# 10368.jpg predicted as plastic bag
# 10369.jpg predicted as tiger cat
# 1037.jpg predicted as Arctic fox
# 10370.jpg predicted as Egyptian cat
# 10371.jpg predicted as tabby
# 10372.jpg predicted as handkerchief
# 10373.jpg predicted as Persian cat
# 10374.jpg predicted as bathtub
# 10375.jpg predicted as Persian cat
# 10376.jpg predicted as Persian cat
# 10377.jpg predicted as tabby
# 10378.jpg predicted as Egyptian cat
# 10379.jpg predicted as Egyptian cat
# 1038.jpg predicted as Egyptian cat
# 10380.jpg predicted as Egyptian cat
# 10381.jpg predicted as Egyptian cat
# 10382.jpg predicted as Egyptian cat
# 10383.jpg predicted as Egyptian cat
# 10384.jpg predicted as Egyptian cat
# 10385.jpg predicted as diaper
# 10386.jpg predicted as tiger cat
# 10387.jpg predicted as Persian cat
# 10388.jpg predicted as Egyptian cat
# 10389.jpg predicted as bath towel
# 1039.jpg predicted as plastic bag
# 10390.jpg predicted as Egyptian cat
# 10391.jpg predicted as Siberian husky
# 10392.jpg predicted as sweatshirt
# 10393.jpg predicted as paper towel
# 10394.jpg predicted as tabby
# 10395.jpg predicted as window screen
# 10396.jpg predicted as trilobite
# 10397.jpg predicted as bassinet
# 10398.jpg predicted as Persian cat
# 10399.jpg predicted as tabby
# 104.jpg predicted as Egyptian cat
# 1040.jpg predicted as Egyptian cat
# 10400.jpg predicted as Egyptian cat
# 10401.jpg predicted as Egyptian cat
# 10402.jpg predicted as tiger cat
# 10403.jpg predicted as hamster
# 10404.jpg predicted as tabby
# 10405.jpg predicted as tabby
# 10406.jpg predicted as bathtub
# 10407.jpg predicted as plastic bag
# 10408.jpg predicted as paper towel
# 10409.jpg predicted as Siamese cat
# 1041.jpg predicted as Egyptian cat
# 10410.jpg predicted as Persian cat
# 10411.jpg predicted as Egyptian cat
# 10412.jpg predicted as Egyptian cat
# 10413.jpg predicted as tabby
# 10414.jpg predicted as Persian cat
# 10415.jpg predicted as Persian cat
# 10416.jpg predicted as bathtub
# 10417.jpg predicted as Persian cat
# 10418.jpg predicted as Siberian husky
# 10419.jpg predicted as paper towel
# 1042.jpg predicted as lynx
# 10420.jpg predicted as Siamese cat
# 10421.jpg predicted as Egyptian cat
# 10422.jpg predicted as Egyptian cat
# 10423.jpg predicted as shopping cart
# 10424.jpg predicted as Egyptian cat
# 10425.jpg predicted as computer keyboard
# 10426.jpg predicted as Siamese cat
# 10427.jpg predicted as Siberian husky
# 10428.jpg predicted as Angora
# 10429.jpg predicted as Egyptian cat
# 1043.jpg predicted as bathtub
# 10430.jpg predicted as Eskimo dog
# 10431.jpg predicted as Egyptian cat
# 10432.jpg predicted as Arctic fox
# 10433.jpg predicted as Siamese cat
# 10434.jpg predicted as tabby
# 10435.jpg predicted as bathtub
# 10436.jpg predicted as Persian cat
# 10437.jpg predicted as Egyptian cat
# 10438.jpg predicted as Siamese cat
# 10439.jpg predicted as Cardigan
# 1044.jpg predicted as Egyptian cat
# 10440.jpg predicted as Egyptian cat
# 10441.jpg predicted as mosquito net
# 10442.jpg predicted as plastic bag
# 10443.jpg predicted as paper towel
# 10444.jpg predicted as Egyptian cat
# 10445.jpg predicted as Egyptian cat
# 10446.jpg predicted as Egyptian cat
# 10447.jpg predicted as Egyptian cat
# 10448.jpg predicted as Egyptian cat
# 10449.jpg predicted as Egyptian cat
# 1045.jpg predicted as Arctic fox
# 10450.jpg predicted as shower curtain
# 10451.jpg predicted as Egyptian cat
# 10452.jpg predicted as Egyptian cat
# 10453.jpg predicted as tabby
# 10454.jpg predicted as paper towel
# 10455.jpg predicted as Persian cat
# 10456.jpg predicted as Egyptian cat
# 10457.jpg predicted as mosquito net
# 10458.jpg predicted as plastic bag
# 10459.jpg predicted as wood rabbit
# 1046.jpg predicted as Egyptian cat
# 10460.jpg predicted as Egyptian cat
# 10461.jpg predicted as Persian cat
# 10462.jpg predicted as tiger cat
# 10463.jpg predicted as Egyptian cat
# 10464.jpg predicted as Egyptian cat
# 10465.jpg predicted as Arctic fox
# 10466.jpg predicted as Egyptian cat
# 10467.jpg predicted as Samoyed
# 10468.jpg predicted as Egyptian cat
# 10469.jpg predicted as Egyptian cat
# 1047.jpg predicted as Egyptian cat
# 10470.jpg predicted as Egyptian cat
# 10471.jpg predicted as Arctic fox
# 10472.jpg predicted as Egyptian cat
# 10473.jpg predicted as Egyptian cat
# 10474.jpg predicted as plastic bag
# 10475.jpg predicted as Arctic fox
# 10476.jpg predicted as shower curtain
# 10477.jpg predicted as mosquito net
# 10478.jpg predicted as Egyptian cat
# 10479.jpg predicted as bassinet
# 1048.jpg predicted as quilt
# 10480.jpg predicted as Egyptian cat
# 10481.jpg predicted as Egyptian cat
# 10482.jpg predicted as Egyptian cat
# 10483.jpg predicted as Persian cat
# 10484.jpg predicted as Egyptian cat
# 10485.jpg predicted as Persian cat
# 10486.jpg predicted as Persian cat
# 10487.jpg predicted as Egyptian cat
# 10488.jpg predicted as tiger cat
# 10489.jpg predicted as paper towel
# 1049.jpg predicted as Angora
# 10490.jpg predicted as Arctic fox
# 10491.jpg predicted as Egyptian cat
# 10492.jpg predicted as tabby
# 10493.jpg predicted as Persian cat
# 10494.jpg predicted as plastic bag
# 10495.jpg predicted as tabby
# 10496.jpg predicted as Persian cat
# 10497.jpg predicted as shower cap
# 10498.jpg predicted as Siamese cat
# 10499.jpg predicted as Persian cat
# 105.jpg predicted as Angora
# 1050.jpg predicted as shower cap
# 10500.jpg predicted as bath towel
# 10501.jpg is a black and white image
# 10502.jpg predicted as Persian cat
# 10503.jpg predicted as Egyptian cat
# 10504.jpg predicted as plastic bag
# 10505.jpg predicted as Persian cat
# 10506.jpg predicted as shower curtain
# 10507.jpg predicted as plastic bag
# 10508.jpg predicted as paper towel
# 10509.jpg predicted as lynx
# 1051.jpg predicted as Egyptian cat
# 10510.jpg predicted as Egyptian cat
# 10511.jpg predicted as Egyptian cat
# 10512.jpg predicted as window screen
# 10513.jpg predicted as Egyptian cat
# 10514.jpg predicted as Persian cat
# 10515.jpg predicted as feather boa
# 10516.jpg predicted as tiger cat
# 10517.jpg predicted as Egyptian cat
# 10518.jpg predicted as Egyptian cat
# 10519.jpg predicted as Egyptian cat
# 1052.jpg predicted as Egyptian cat
# 10520.jpg predicted as Eskimo dog
# 10521.jpg predicted as mosquito net
# 10522.jpg predicted as Pembroke
# 10523.jpg predicted as Egyptian cat
# 10524.jpg predicted as mosquito net
# 10525.jpg predicted as tiger cat
# 10526.jpg predicted as Egyptian cat
# 10527.jpg predicted as hamper
# 10528.jpg predicted as Egyptian cat
# 10529.jpg predicted as Egyptian cat
# 1053.jpg predicted as window screen
# 10530.jpg predicted as Egyptian cat
# 10531.jpg predicted as bathtub
# 10532.jpg predicted as Maltese dog
# 10533.jpg predicted as tiger cat
# 10534.jpg predicted as tabby
# 10535.jpg predicted as Egyptian cat
# 10536.jpg predicted as toilet tissue
# 10537.jpg predicted as Egyptian cat
# 10538.jpg predicted as shower curtain
# 10539.jpg predicted as clumber
# 1054.jpg predicted as paper towel
# 10540.jpg predicted as tabby
# 10541.jpg predicted as Siamese cat
# 10542.jpg predicted as Egyptian cat
# 10543.jpg predicted as tiger cat
# 10544.jpg predicted as Egyptian cat
# 10545.jpg predicted as Egyptian cat
# 10546.jpg predicted as mosquito net
# 10547.jpg predicted as bib
# 10548.jpg predicted as Angora
# 10549.jpg predicted as shower curtain
# 1055.jpg predicted as Egyptian cat
# 10550.jpg predicted as plastic bag
# 10551.jpg predicted as Egyptian cat
# 10552.jpg predicted as Persian cat
# 10553.jpg predicted as plastic bag
# 10554.jpg predicted as Egyptian cat
# 10555.jpg predicted as tiger cat
# 10556.jpg predicted as tabby
# 10557.jpg predicted as Persian cat
# 10558.jpg predicted as Egyptian cat
# 10559.jpg predicted as Egyptian cat
# 1056.jpg predicted as Egyptian cat
# 10560.jpg predicted as tabby
# 10561.jpg predicted as plastic bag
# 10562.jpg predicted as paper towel
# 10563.jpg predicted as Arctic fox
# 10564.jpg predicted as paper towel
# 10565.jpg predicted as washbasin
# 10566.jpg predicted as lynx
# 10567.jpg predicted as Persian cat
# 10568.jpg predicted as Siamese cat
# 10569.jpg predicted as hamster
# 1057.jpg predicted as tiger cat
# 10570.jpg predicted as Arctic fox
# 10571.jpg predicted as Egyptian cat
# 10572.jpg predicted as bloodhound
# 10573.jpg predicted as Egyptian cat
# 10574.jpg predicted as bassinet
# 10575.jpg predicted as Samoyed
# 10576.jpg predicted as Persian cat
# 10577.jpg predicted as Egyptian cat
# 10578.jpg predicted as Labrador retriever
# 10579.jpg predicted as microwave
# 1058.jpg predicted as Egyptian cat
# 10580.jpg predicted as tabby
# 10581.jpg predicted as shower curtain
# 10582.jpg predicted as Egyptian cat
# 10583.jpg predicted as tabby
# 10584.jpg predicted as hammerhead
# 10585.jpg predicted as Siamese cat
# 10586.jpg predicted as Egyptian cat
# 10587.jpg predicted as macaque
# 10588.jpg predicted as Persian cat
# 10589.jpg predicted as shower curtain
# 1059.jpg predicted as bucket
# 10590.jpg predicted as diaper
# 10591.jpg predicted as Arctic fox
# 10592.jpg predicted as Egyptian cat
# 10593.jpg predicted as schipperke
# 10594.jpg predicted as Egyptian cat
# 10595.jpg predicted as tiger cat
# 10596.jpg predicted as Boston bull
# 10597.jpg predicted as white wolf
# 10598.jpg predicted as paper towel
# 10599.jpg predicted as tub
# 106.jpg predicted as paper towel
# 1060.jpg predicted as hare
# 10600.jpg predicted as Persian cat
# 10601.jpg predicted as diaper
# 10602.jpg predicted as plastic bag
# 10603.jpg predicted as basenji
# 10604.jpg predicted as Egyptian cat
# 10605.jpg predicted as Christmas stocking
# 10606.jpg predicted as plastic bag
# 10607.jpg predicted as Eskimo dog
# 10608.jpg predicted as Egyptian cat
# 10609.jpg predicted as handkerchief
# 1061.jpg predicted as paper towel
# 10610.jpg predicted as Angora
# 10611.jpg predicted as tiger cat
# 10612.jpg predicted as jellyfish
# 10613.jpg predicted as Egyptian cat
# 10614.jpg predicted as Brabancon griffon
# 10615.jpg predicted as Egyptian cat
# 10616.jpg predicted as Egyptian cat
# 10617.jpg predicted as shower curtain
# 10618.jpg predicted as bucket
# 10619.jpg predicted as Egyptian cat
# 1062.jpg predicted as Egyptian cat
# 10620.jpg predicted as oxygen mask
# 10621.jpg predicted as Egyptian cat
# 10622.jpg predicted as Egyptian cat
# 10623.jpg predicted as Persian cat
# 10624.jpg predicted as Arctic fox
# 10625.jpg predicted as Maltese dog
# 10626.jpg predicted as Egyptian cat
# 10627.jpg predicted as plastic bag
# 10628.jpg predicted as dingo
# 10629.jpg predicted as paper towel
# 1063.jpg predicted as tabby
# 10630.jpg predicted as Egyptian cat
# 10631.jpg predicted as tabby
# 10632.jpg predicted as Siberian husky
# 10633.jpg predicted as book jacket
# 10634.jpg predicted as Persian cat
# 10635.jpg predicted as snowplow
# 10636.jpg predicted as tray
# 10637.jpg predicted as shower curtain
# 10638.jpg predicted as lynx
# 10639.jpg predicted as Eskimo dog
# 1064.jpg predicted as Egyptian cat
# 10640.jpg predicted as Siamese cat
# 10641.jpg predicted as Egyptian cat
# 10642.jpg predicted as plastic bag
# 10643.jpg predicted as Persian cat
# 10644.jpg predicted as tabby
# 10645.jpg predicted as Egyptian cat
# 10646.jpg predicted as Angora
# 10647.jpg predicted as Persian cat
# 10648.jpg predicted as Egyptian cat
# 10649.jpg predicted as West Highland white terrier
# 1065.jpg predicted as paper towel
# 10650.jpg predicted as Egyptian cat
# 10651.jpg predicted as dingo
# 10652.jpg predicted as Persian cat
# 10653.jpg predicted as paper towel
# 10654.jpg predicted as Egyptian cat
# 10655.jpg predicted as bathtub
# 10656.jpg predicted as Egyptian cat
# 10657.jpg predicted as Egyptian cat
# 10658.jpg predicted as lynx
# 10659.jpg predicted as malamute
# 1066.jpg predicted as Angora
# 10660.jpg predicted as Egyptian cat
# 10661.jpg predicted as Egyptian cat
# 10662.jpg predicted as Egyptian cat
# 10663.jpg predicted as Egyptian cat
# 10664.jpg predicted as Samoyed
# 10665.jpg predicted as tabby
# 10666.jpg predicted as tabby
# 10667.jpg predicted as weasel
# 10668.jpg predicted as Egyptian cat
# 10669.jpg predicted as Persian cat
# 1067.jpg predicted as Egyptian cat
# 10670.jpg predicted as fire screen
# 10671.jpg predicted as Persian cat
# 10672.jpg predicted as Egyptian cat
# 10673.jpg predicted as handkerchief
# 10674.jpg predicted as hamper
# 10675.jpg predicted as Egyptian cat
# 10676.jpg predicted as carton
# 10677.jpg predicted as Egyptian cat
# 10678.jpg predicted as wardrobe
# 10679.jpg predicted as Egyptian cat
# 1068.jpg predicted as Egyptian cat
# 10680.jpg predicted as Egyptian cat
# 10681.jpg predicted as Siberian husky
# 10682.jpg predicted as Egyptian cat
# 10683.jpg predicted as Persian cat
# 10684.jpg predicted as Egyptian cat
# 10685.jpg predicted as lynx
# 10686.jpg predicted as Egyptian cat
# 10687.jpg predicted as tabby
# 10688.jpg predicted as Egyptian cat
# 10689.jpg predicted as Siamese cat
# 1069.jpg predicted as schipperke
# 10690.jpg predicted as mosquito net
# 10691.jpg predicted as Egyptian cat
# 10692.jpg predicted as Arctic fox
# 10693.jpg predicted as shower curtain
# 10694.jpg predicted as Egyptian cat
# 10695.jpg predicted as Persian cat
# 10696.jpg predicted as Arctic fox
# 10697.jpg predicted as hamster
# 10698.jpg predicted as Egyptian cat
# 10699.jpg predicted as Egyptian cat
# 107.jpg predicted as Egyptian cat
# 1070.jpg predicted as Egyptian cat
# 10700.jpg predicted as golfcart
# 10701.jpg predicted as Egyptian cat
# 10702.jpg predicted as Persian cat
# 10703.jpg predicted as tub
# 10704.jpg predicted as Egyptian cat
# 10705.jpg predicted as German shepherd
# 10706.jpg predicted as Persian cat
# 10707.jpg predicted as tiger cat
# 10708.jpg predicted as plastic bag
# 10709.jpg predicted as Siamese cat
# 1071.jpg predicted as Egyptian cat
# 10710.jpg predicted as Egyptian cat
# 10711.jpg predicted as Egyptian cat
# 10712.jpg predicted as street sign
# 10713.jpg predicted as Angora
# 10714.jpg predicted as Arctic fox
# 10715.jpg predicted as Persian cat
# 10716.jpg predicted as white wolf
# 10717.jpg predicted as Arctic fox
# 10718.jpg predicted as Egyptian cat
# 10719.jpg predicted as Egyptian cat
# 1072.jpg predicted as Egyptian cat
# 10720.jpg predicted as piggy bank
# 10721.jpg predicted as washbasin
# 10722.jpg predicted as mosquito net
# 10723.jpg predicted as tabby
# 10724.jpg predicted as Egyptian cat
# 10725.jpg predicted as Egyptian cat
# 10726.jpg predicted as Egyptian cat
# 10727.jpg predicted as tabby
# 10728.jpg predicted as Egyptian cat
# 10729.jpg predicted as Egyptian cat
# 1073.jpg predicted as Egyptian cat
# 10730.jpg predicted as Egyptian cat
# 10731.jpg predicted as Persian cat
# 10732.jpg predicted as bassinet
# 10733.jpg predicted as bathtub
# 10734.jpg predicted as feather boa
# 10735.jpg predicted as Egyptian cat
# 10736.jpg predicted as bassinet
# 10737.jpg predicted as Egyptian cat
# 10738.jpg predicted as mosquito net
# 10739.jpg predicted as water snake
# 1074.jpg predicted as Samoyed
# 10740.jpg predicted as wallaby
# 10741.jpg predicted as toilet seat
# 10742.jpg predicted as Persian cat
# 10743.jpg predicted as bathtub
# 10744.jpg predicted as Persian cat
# 10745.jpg predicted as Egyptian cat
# 10746.jpg predicted as Egyptian cat
# 10747.jpg predicted as leatherback turtle
# 10748.jpg predicted as Angora
# 10749.jpg predicted as Egyptian cat
# 1075.jpg predicted as Egyptian cat
# 10750.jpg predicted as plastic bag
# 10751.jpg predicted as bathtub
# 10752.jpg predicted as Egyptian cat
# 10753.jpg predicted as mosquito net
# 10754.jpg predicted as lynx
# 10755.jpg predicted as tabby
# 10756.jpg predicted as bassinet
# 10757.jpg predicted as bathtub
# 10758.jpg predicted as tiger cat
# 10759.jpg predicted as Egyptian cat
# 1076.jpg predicted as tiger cat
# 10760.jpg predicted as Persian cat
# 10761.jpg predicted as Persian cat
# 10762.jpg predicted as bassinet
# 10763.jpg predicted as lynx
# 10764.jpg predicted as Egyptian cat
# 10765.jpg predicted as Siberian husky
# 10766.jpg predicted as plastic bag
# 10767.jpg predicted as Siberian husky
# 10768.jpg predicted as paper towel
# 10769.jpg predicted as Egyptian cat
# 1077.jpg predicted as mosquito net
# 10770.jpg predicted as Egyptian cat
# 10771.jpg predicted as Arctic fox
# 10772.jpg predicted as Egyptian cat
# 10773.jpg predicted as Siamese cat
# 10774.jpg predicted as washer
# 10775.jpg predicted as hamster
# 10776.jpg predicted as Egyptian cat
# 10777.jpg predicted as plastic bag
# 10778.jpg predicted as schipperke
# 10779.jpg predicted as schipperke
# 1078.jpg predicted as Siamese cat
# 10780.jpg predicted as tub
# 10781.jpg predicted as Egyptian cat
# 10782.jpg predicted as Egyptian cat
# 10783.jpg predicted as Persian cat
# 10784.jpg predicted as Siamese cat
# 10785.jpg predicted as Egyptian cat
# 10786.jpg predicted as Egyptian cat
# 10787.jpg predicted as cradle
# 10788.jpg predicted as Egyptian cat
# 10789.jpg predicted as Persian cat
# 1079.jpg predicted as Siamese cat
# 10790.jpg predicted as lynx
# 10791.jpg predicted as tiger cat
# 10792.jpg predicted as Persian cat
# 10793.jpg predicted as Egyptian cat
# 10794.jpg predicted as hammerhead
# 10795.jpg predicted as Egyptian cat
# 10796.jpg predicted as cradle
# 10797.jpg predicted as Egyptian cat
# 10798.jpg predicted as Egyptian cat
# 10799.jpg predicted as Egyptian cat
# 108.jpg predicted as toilet tissue
# 1080.jpg predicted as mongoose
# 10800.jpg predicted as paper towel
# 10801.jpg predicted as Egyptian cat
# 10802.jpg predicted as tub
# 10803.jpg predicted as Egyptian cat
# 10804.jpg predicted as Persian cat
# 10805.jpg predicted as paper towel
# 10806.jpg predicted as bathtub
# 10807.jpg predicted as Samoyed
# 10808.jpg predicted as paper towel
# 10809.jpg predicted as tabby
# 1081.jpg predicted as Arctic fox
# 10810.jpg predicted as Egyptian cat
# 10811.jpg predicted as Great Pyrenees
# 10812.jpg predicted as tabby
# 10813.jpg predicted as Egyptian cat
# 10814.jpg predicted as Siamese cat
# 10815.jpg predicted as Egyptian cat
# 10816.jpg predicted as Egyptian cat
# 10817.jpg predicted as tiger cat
# 10818.jpg predicted as tiger cat
# 10819.jpg predicted as Egyptian cat
# 1082.jpg predicted as Persian cat
# 10820.jpg is a black and white image
# 10821.jpg predicted as toilet seat
# 10822.jpg predicted as Persian cat
# 10823.jpg predicted as wombat
# 10824.jpg predicted as Egyptian cat
# 10825.jpg predicted as washbasin
# 10826.jpg predicted as plastic bag
# 10827.jpg predicted as Samoyed
# 10828.jpg predicted as Egyptian cat
# 10829.jpg predicted as weasel
# 1083.jpg predicted as Egyptian cat
# 10830.jpg predicted as Egyptian cat
# 10831.jpg predicted as refrigerator
# 10832.jpg predicted as Samoyed
# 10833.jpg predicted as Samoyed
# 10834.jpg predicted as book jacket
# 10835.jpg predicted as plastic bag
# 10836.jpg predicted as Siamese cat
# 10837.jpg predicted as Siamese cat
# 10838.jpg predicted as paper towel
# 10839.jpg predicted as crossword puzzle
# 1084.jpg predicted as Egyptian cat
# 10840.jpg predicted as Egyptian cat
# 10841.jpg predicted as bath towel
# 10842.jpg predicted as Egyptian cat
# 10843.jpg predicted as Persian cat
# 10844.jpg predicted as Egyptian cat
# 10845.jpg predicted as Egyptian cat
# 10846.jpg predicted as Egyptian cat
# 10847.jpg predicted as Egyptian cat
# 10848.jpg predicted as Egyptian cat
# 10849.jpg predicted as Siberian husky
# 1085.jpg predicted as plastic bag
# 10850.jpg predicted as plastic bag
# 10851.jpg predicted as hamster
# 10852.jpg predicted as Egyptian cat
# 10853.jpg predicted as tabby
# 10854.jpg predicted as Siberian husky
# 10855.jpg predicted as Egyptian cat
# 10856.jpg predicted as Egyptian cat
# 10857.jpg predicted as toilet tissue
# 10858.jpg predicted as Egyptian cat
# 10859.jpg predicted as dishwasher
# 1086.jpg predicted as toilet tissue
# 10860.jpg predicted as mosquito net
# 10861.jpg predicted as tabby
# 10862.jpg predicted as plastic bag
# 10863.jpg predicted as mosquito net
# 10864.jpg predicted as barrow
# 10865.jpg predicted as Persian cat
# 10866.jpg predicted as tabby
# 10867.jpg predicted as Persian cat
# 10868.jpg predicted as Egyptian cat
# 10869.jpg predicted as tiger cat
# 1087.jpg predicted as Persian cat
# 10870.jpg predicted as Egyptian cat
# 10871.jpg predicted as Persian cat
# 10872.jpg predicted as Siamese cat
# 10873.jpg predicted as Egyptian cat
# 10874.jpg predicted as Siamese cat
# 10875.jpg predicted as Egyptian cat
# 10876.jpg predicted as bassinet
# 10877.jpg predicted as tabby
# 10878.jpg predicted as Egyptian cat
# 10879.jpg predicted as lynx
# 1088.jpg predicted as schipperke
# 10880.jpg predicted as oxygen mask
# 10881.jpg predicted as toilet tissue
# 10882.jpg predicted as Persian cat
# 10883.jpg predicted as Egyptian cat
# 10884.jpg predicted as window screen
# 10885.jpg predicted as tabby
# 10886.jpg predicted as toilet tissue
# 10887.jpg predicted as Egyptian cat
# 10888.jpg predicted as lynx
# 10889.jpg predicted as studio couch
# 1089.jpg predicted as washbasin
# 10890.jpg predicted as Egyptian cat
# 10891.jpg predicted as ice bear
# 10892.jpg predicted as Siamese cat
# 10893.jpg predicted as toilet seat
# 10894.jpg predicted as Egyptian cat
# 10895.jpg predicted as washbasin
# 10896.jpg predicted as Egyptian cat
# 10897.jpg predicted as Siberian husky
# 10898.jpg predicted as tub
# 10899.jpg predicted as Egyptian cat
# 109.jpg predicted as Egyptian cat
# 1090.jpg predicted as hammerhead
# 10900.jpg predicted as Persian cat
# 10901.jpg predicted as mosquito net
# 10902.jpg predicted as Egyptian cat
# 10903.jpg predicted as carton
# 10904.jpg predicted as Siamese cat
# 10905.jpg predicted as bathtub
# 10906.jpg predicted as mousetrap
# 10907.jpg predicted as Persian cat
# 10908.jpg predicted as mosquito net
# 10909.jpg predicted as tabby
# 1091.jpg predicted as tub
# 10910.jpg predicted as Egyptian cat
# 10911.jpg predicted as Angora
# 10912.jpg predicted as bassinet
# 10913.jpg predicted as mosquito net
# 10914.jpg predicted as Egyptian cat
# 10915.jpg predicted as Egyptian cat
# 10916.jpg predicted as Egyptian cat
# 10917.jpg predicted as Egyptian cat
# 10918.jpg predicted as plastic bag
# 10919.jpg predicted as Arctic fox
# 1092.jpg predicted as Siamese cat
# 10920.jpg predicted as Persian cat
# 10921.jpg predicted as Persian cat
# 10922.jpg predicted as tabby
# 10923.jpg predicted as tabby
# 10924.jpg predicted as Samoyed
# 10925.jpg predicted as Persian cat
# 10926.jpg predicted as bathtub
# 10927.jpg predicted as West Highland white terrier
# 10928.jpg predicted as Siamese cat
# 10929.jpg predicted as Egyptian cat
# 1093.jpg predicted as paper towel
# 10930.jpg predicted as shower curtain
# 10931.jpg predicted as Christmas stocking
# 10932.jpg predicted as toilet tissue
# 10933.jpg predicted as toilet seat
# 10934.jpg predicted as bathtub
# 10935.jpg predicted as Persian cat
# 10936.jpg predicted as Siberian husky
# 10937.jpg predicted as Egyptian cat
# 10938.jpg predicted as plastic bag
# 10939.jpg predicted as carton
# 1094.jpg predicted as Egyptian cat
# 10940.jpg predicted as handkerchief
# 10941.jpg predicted as Siamese cat
# 10942.jpg predicted as plastic bag
# 10943.jpg predicted as kelpie
# 10944.jpg predicted as paper towel
# 10945.jpg predicted as medicine chest
# 10946.jpg predicted as bow tie
# 10947.jpg predicted as Persian cat
# 10948.jpg predicted as Arctic fox
# 10949.jpg predicted as Egyptian cat
# 1095.jpg predicted as Persian cat
# 10950.jpg predicted as bathtub
# 10951.jpg predicted as quilt
# 10952.jpg predicted as Egyptian cat
# 10953.jpg predicted as Egyptian cat
# 10954.jpg predicted as lynx
# 10955.jpg predicted as Persian cat
# 10956.jpg predicted as tabby
# 10957.jpg predicted as Egyptian cat
# 10958.jpg predicted as paper towel
# 10959.jpg predicted as Egyptian cat
# 1096.jpg predicted as Egyptian cat
# 10960.jpg predicted as plastic bag
# 10961.jpg predicted as plastic bag
# 10962.jpg predicted as Egyptian cat
# 10963.jpg predicted as Egyptian cat
# 10964.jpg predicted as Persian cat
# 10965.jpg predicted as paper towel
# 10966.jpg predicted as stingray
# 10967.jpg predicted as Egyptian cat
# 10968.jpg predicted as Egyptian cat
# 10969.jpg predicted as Siberian husky
# 1097.jpg predicted as hamper
# 10970.jpg predicted as Egyptian cat
# 10971.jpg predicted as Egyptian cat
# 10972.jpg predicted as Egyptian cat
# 10973.jpg predicted as Persian cat
# 10974.jpg predicted as Egyptian cat
# 10975.jpg predicted as Samoyed
# 10976.jpg predicted as Eskimo dog
# 10977.jpg predicted as Egyptian cat
# 10978.jpg predicted as Persian cat
# 10979.jpg predicted as German shepherd
# 1098.jpg predicted as bathtub
# 10980.jpg predicted as paper towel
# 10981.jpg predicted as window screen
# 10982.jpg predicted as Egyptian cat
# 10983.jpg predicted as Egyptian cat
# 10984.jpg predicted as Egyptian cat
# 10985.jpg predicted as dishwasher
# 10986.jpg predicted as Siamese cat
# 10987.jpg predicted as Egyptian cat
# 10988.jpg predicted as Arctic fox
# 10989.jpg predicted as plastic bag
# 1099.jpg predicted as fire screen
# 10990.jpg predicted as Egyptian cat
# 10991.jpg predicted as Egyptian cat
# 10992.jpg predicted as paper towel
# 10993.jpg predicted as Egyptian cat
# 10994.jpg predicted as shower curtain
# 10995.jpg predicted as Persian cat
# 10996.jpg predicted as feather boa
# 10997.jpg predicted as window screen
# 10998.jpg predicted as mosquito net
# 10999.jpg predicted as Egyptian cat
# 11.jpg predicted as Egyptian cat
# 110.jpg predicted as Persian cat
# 1100.jpg predicted as Persian cat
# 11000.jpg predicted as Persian cat
# 11001.jpg predicted as Angora
# 11002.jpg predicted as Indian elephant
# 11003.jpg predicted as Egyptian cat
# 11004.jpg predicted as toilet tissue
# 11005.jpg predicted as Egyptian cat
# 11006.jpg predicted as tiger cat
# 11007.jpg predicted as plastic bag
# 11008.jpg predicted as paper towel
# 11009.jpg predicted as Persian cat
# 1101.jpg predicted as quilt
# 11010.jpg predicted as tiger cat
# 11011.jpg predicted as Persian cat
# 11012.jpg predicted as Siamese cat
# 11013.jpg predicted as tiger cat
# 11014.jpg predicted as bassinet
# 11015.jpg predicted as Egyptian cat
# 11016.jpg predicted as Persian cat
# 11017.jpg predicted as plastic bag
# 11018.jpg predicted as Persian cat
# 11019.jpg predicted as Egyptian cat
# 1102.jpg predicted as lab coat
# 11020.jpg predicted as tabby
# 11021.jpg predicted as Egyptian cat
# 11022.jpg predicted as Siamese cat
# 11023.jpg predicted as bassinet
# 11024.jpg predicted as Egyptian cat
# 11025.jpg predicted as plastic bag
# 11026.jpg predicted as Egyptian cat
# 11027.jpg predicted as plastic bag
# 11028.jpg predicted as Pembroke
# 11029.jpg predicted as Persian cat
# 1103.jpg predicted as Egyptian cat
# 11030.jpg predicted as Egyptian cat
# 11031.jpg predicted as hamster
# 11032.jpg predicted as Egyptian cat
# 11033.jpg predicted as tiger cat
# 11034.jpg predicted as Egyptian cat
# 11035.jpg predicted as iPod
# 11036.jpg predicted as cowboy hat
# 11037.jpg predicted as bassinet
# 11038.jpg predicted as toilet seat
# 11039.jpg predicted as lab coat
# 1104.jpg predicted as schipperke
# 11040.jpg predicted as Egyptian cat
# 11041.jpg predicted as miniature pinscher
# 11042.jpg predicted as Egyptian cat
# 11043.jpg predicted as Egyptian cat
# 11044.jpg predicted as schipperke
# 11045.jpg predicted as pedestal
# 11046.jpg predicted as tub
# 11047.jpg predicted as Egyptian cat
# 11048.jpg predicted as Egyptian cat
# 11049.jpg predicted as Siamese cat
# 1105.jpg predicted as plastic bag
# 11050.jpg predicted as Siberian husky
# 11051.jpg predicted as bucket
# 11052.jpg predicted as schipperke
# 11053.jpg predicted as tiger cat
# 11054.jpg predicted as Persian cat
# 11055.jpg predicted as shower curtain
# 11056.jpg predicted as Arctic fox
# 11057.jpg predicted as Egyptian cat
# 11058.jpg predicted as Egyptian cat
# 11059.jpg predicted as paper towel
# 1106.jpg predicted as Egyptian cat
# 11060.jpg predicted as Maltese dog
# 11061.jpg predicted as Arctic fox
# 11062.jpg predicted as shovel
# 11063.jpg predicted as Egyptian cat
# 11064.jpg predicted as Egyptian cat
# 11065.jpg predicted as Egyptian cat
# 11066.jpg predicted as shower curtain
# 11067.jpg predicted as window screen
# 11068.jpg predicted as plastic bag
# 11069.jpg predicted as tabby
# 1107.jpg predicted as bib
# 11070.jpg predicted as Arctic fox
# 11071.jpg predicted as Siamese cat
# 11072.jpg predicted as washbasin
# 11073.jpg predicted as Siamese cat
# 11074.jpg predicted as Persian cat
# 11075.jpg predicted as hamster
# 11076.jpg predicted as Egyptian cat
# 11077.jpg predicted as toilet tissue
# 11078.jpg predicted as Egyptian cat
# 11079.jpg predicted as shower curtain
# 1108.jpg predicted as bath towel
# 11080.jpg predicted as lynx
# 11081.jpg predicted as plastic bag
# 11082.jpg predicted as Siamese cat
# 11083.jpg predicted as fire screen
# 11084.jpg predicted as Persian cat
# 11085.jpg predicted as mosquito net
# 11086.jpg predicted as Siamese cat
# 11087.jpg predicted as Egyptian cat
# 11088.jpg predicted as Egyptian cat
# 11089.jpg predicted as Egyptian cat
# 1109.jpg predicted as tiger cat
# 11090.jpg predicted as Arctic fox
# 11091.jpg predicted as whiskey jug
# 11092.jpg predicted as Egyptian cat
# 11093.jpg predicted as Eskimo dog
# 11094.jpg predicted as lynx
# 11095.jpg is a black and white image
# 11096.jpg predicted as plastic bag
# 11097.jpg predicted as Eskimo dog
# 11098.jpg predicted as tabby
# 11099.jpg predicted as Egyptian cat
# 111.jpg predicted as Egyptian cat
# 1110.jpg predicted as Siamese cat
# 11100.jpg predicted as Arctic fox
# 11101.jpg predicted as paper towel
# 11102.jpg predicted as washbasin
# 11103.jpg predicted as Egyptian cat
# 11104.jpg predicted as Eskimo dog
# 11105.jpg predicted as Arctic fox
# 11106.jpg predicted as tabby
# 11107.jpg predicted as Egyptian cat
# 11108.jpg predicted as Egyptian cat
# 11109.jpg predicted as Angora
# 1111.jpg predicted as Persian cat
# 11110.jpg predicted as Egyptian cat
# 11111.jpg predicted as Egyptian cat
# 11112.jpg predicted as Egyptian cat
# 11113.jpg predicted as shower curtain
# 11114.jpg predicted as Persian cat
# 11115.jpg predicted as Egyptian cat
# 11116.jpg predicted as Egyptian cat
# 11117.jpg predicted as Egyptian cat
# 11118.jpg predicted as schipperke
# 11119.jpg predicted as tabby
# 1112.jpg predicted as Arctic fox
# 11120.jpg predicted as lynx
# 11121.jpg predicted as Egyptian cat
# 11122.jpg predicted as Egyptian cat
# 11123.jpg predicted as lynx
# 11124.jpg predicted as shower curtain
# 11125.jpg predicted as Chihuahua
# 11126.jpg predicted as Persian cat
# 11127.jpg predicted as Egyptian cat
# 11128.jpg predicted as Egyptian cat
# 11129.jpg predicted as Arctic fox
# 1113.jpg predicted as tiger cat
# 11130.jpg predicted as tiger cat
# 11131.jpg predicted as Persian cat
# 11132.jpg predicted as Egyptian cat
# 11133.jpg predicted as Egyptian cat
# 11134.jpg predicted as paper towel
# 11135.jpg predicted as Egyptian cat
# 11136.jpg predicted as Siamese cat
# 11137.jpg predicted as schipperke
# 11138.jpg predicted as Persian cat
# 11139.jpg predicted as Egyptian cat
# 1114.jpg predicted as cradle
# 11140.jpg predicted as Persian cat
# 11141.jpg predicted as plastic bag
# 11142.jpg predicted as washbasin
# 11143.jpg predicted as tabby
# 11144.jpg predicted as shower curtain
# 11145.jpg predicted as Egyptian cat
# 11146.jpg predicted as weasel
# 11147.jpg predicted as Egyptian cat
# 11148.jpg predicted as Egyptian cat
# 11149.jpg predicted as toy poodle
# 1115.jpg predicted as oxygen mask
# 11150.jpg predicted as Egyptian cat
# 11151.jpg predicted as Egyptian cat
# 11152.jpg predicted as paper towel
# 11153.jpg predicted as paper towel
# 11154.jpg predicted as plastic bag
# 11155.jpg predicted as Persian cat
# 11156.jpg predicted as Siamese cat
# 11157.jpg predicted as Persian cat
# 11158.jpg predicted as paper towel
# 11159.jpg predicted as bathtub
# 1116.jpg predicted as tiger cat
# 11160.jpg predicted as Egyptian cat
# 11161.jpg predicted as tabby
# 11162.jpg predicted as plastic bag
# 11163.jpg predicted as Egyptian cat
# 11164.jpg predicted as shower curtain
# 11165.jpg predicted as Persian cat
# 11166.jpg predicted as Egyptian cat
# 11167.jpg predicted as toilet seat
# 11168.jpg predicted as bassinet
# 11169.jpg predicted as hamper
# 1117.jpg predicted as Persian cat
# 11170.jpg predicted as Persian cat
# 11171.jpg predicted as Persian cat
# 11172.jpg predicted as paper towel
# 11173.jpg predicted as Egyptian cat
# 11174.jpg predicted as Egyptian cat
# 11175.jpg predicted as Arctic fox
# 11176.jpg predicted as Persian cat
# 11177.jpg predicted as Egyptian cat
# 11178.jpg predicted as Egyptian cat
# 11179.jpg predicted as Egyptian cat
# 1118.jpg predicted as bassinet
# 11180.jpg predicted as toilet tissue
# 11181.jpg predicted as Angora
# 11182.jpg predicted as carton
# 11183.jpg predicted as tabby
# 11184.jpg predicted as cleaver
# 11185.jpg predicted as tub
# 11186.jpg predicted as tabby
# 11187.jpg predicted as Egyptian cat
# 11188.jpg predicted as Persian cat
# 11189.jpg predicted as Egyptian cat
# 1119.jpg predicted as paper towel
# 11190.jpg predicted as tiger cat
# 11191.jpg predicted as Pembroke
# 11192.jpg predicted as lynx
# 11193.jpg predicted as Egyptian cat
# 11194.jpg predicted as handkerchief
# 11195.jpg predicted as Egyptian cat
# 11196.jpg predicted as Chihuahua
# 11197.jpg predicted as Persian cat
# 11198.jpg predicted as mosquito net
# 11199.jpg predicted as jellyfish
# 112.jpg predicted as plastic bag
# 1120.jpg predicted as Egyptian cat
# 11200.jpg predicted as Egyptian cat
# 11201.jpg predicted as Persian cat
# 11202.jpg predicted as toilet seat
# 11203.jpg predicted as Persian cat
# 11204.jpg predicted as Egyptian cat
# 11205.jpg predicted as toilet tissue
# 11206.jpg predicted as Egyptian cat
# 11207.jpg predicted as Persian cat
# 11208.jpg predicted as tub
# 11209.jpg predicted as Egyptian cat
# 1121.jpg predicted as bathtub
# 11210.jpg is a black and white image
# 11211.jpg predicted as mosquito net
# 11212.jpg predicted as lynx
# 11213.jpg predicted as paper towel
# 11214.jpg predicted as Egyptian cat
# 11215.jpg predicted as dugong
# 11216.jpg predicted as Arctic fox
# 11217.jpg predicted as plastic bag
# 11218.jpg predicted as Persian cat
# 11219.jpg predicted as Egyptian cat
# 1122.jpg predicted as hamper
# 11220.jpg predicted as shower curtain
# 11221.jpg predicted as Siamese cat
# 11222.jpg predicted as Labrador retriever
# 11223.jpg predicted as Egyptian cat
# 11224.jpg predicted as Persian cat
# 11225.jpg predicted as Egyptian cat
# 11226.jpg predicted as shower curtain
# 11227.jpg predicted as lab coat
# 11228.jpg predicted as Angora
# 11229.jpg predicted as lynx
# 1123.jpg predicted as radiator
# 11230.jpg predicted as cradle
# 11231.jpg predicted as book jacket
# 11232.jpg predicted as Egyptian cat
# 11233.jpg predicted as carton
# 11234.jpg predicted as Egyptian cat
# 11235.jpg predicted as shower cap
# 11236.jpg predicted as bath towel
# 11237.jpg predicted as plastic bag
# 11238.jpg predicted as Persian cat
# 11239.jpg predicted as Persian cat
# 1124.jpg predicted as plastic bag
# 11240.jpg predicted as tiger cat
# 11241.jpg predicted as plastic bag
# 11242.jpg predicted as Egyptian cat
# 11243.jpg predicted as sliding door
# 11244.jpg predicted as bassinet
# 11245.jpg predicted as paper towel
# 11246.jpg predicted as tiger cat
# 11247.jpg predicted as Egyptian cat
# 11248.jpg predicted as tabby
# 11249.jpg predicted as bathtub
# 1125.jpg predicted as tub
# 11250.jpg predicted as Egyptian cat
# 11251.jpg predicted as bonnet
# 11252.jpg predicted as Persian cat
# 11253.jpg predicted as Persian cat
# 11254.jpg predicted as Persian cat
# 11255.jpg predicted as paper towel
# ...
# 11688.jpg predicted as bow tie
# 11689.jpg predicted as plastic bag
# 1169.jpg predicted as Persian cat
# 11690.jpg predicted as bathtub
# 11691.jpg predicted as Border collie
# 11692.jpg predicted as Persian cat
# 11693.jpg predicted as tabby
# 11694.jpg predicted as tabby
# 11695.jpg predicted as lynx
# 11696.jpg predicted as paper towel
# 11697.jpg predicted as tabby
# 11698.jpg predicted as tub
# 11699.jpg predicted as Egyptian cat
# 117.jpg predicted as tabby
# 1170.jpg predicted as plastic bag
# 11700.jpg predicted as paper towel
# 11701.jpg predicted as sleeping bag
# 11702.jpg predicted as weasel
# 11703.jpg predicted as Persian cat
# 11704.jpg predicted as toilet tissue
# 11705.jpg predicted as piggy bank
# 11706.jpg predicted as mosquito net
# 11707.jpg predicted as Egyptian cat
# 11708.jpg predicted as tiger cat
# 11709.jpg predicted as Siberian husky
# 1171.jpg predicted as Persian cat
# 11710.jpg predicted as bassinet
# 11711.jpg predicted as tiger cat
# 11712.jpg predicted as Egyptian cat
# 11713.jpg predicted as Egyptian cat
# 11714.jpg predicted as Egyptian cat
# 11715.jpg predicted as tabby
# 11716.jpg predicted as shower curtain
# 11717.jpg predicted as toilet tissue
# 11718.jpg predicted as plastic bag
# 11719.jpg predicted as tabby
# 1172.jpg predicted as plastic bag
# 11720.jpg predicted as Angora
# 11721.jpg predicted as Arctic fox
# 11722.jpg predicted as cradle
# 11723.jpg predicted as Eskimo dog
# 11724.jpg predicted as Labrador retriever
# 11725.jpg predicted as Arctic fox
# 11726.jpg predicted as paper towel
# 11727.jpg predicted as tabby
# 11728.jpg predicted as Persian cat
# 11729.jpg predicted as Egyptian cat
# 1173.jpg predicted as Egyptian cat
# 11730.jpg predicted as Persian cat
# 11731.jpg predicted as Egyptian cat
# 11732.jpg predicted as Egyptian cat
# 11733.jpg predicted as plastic bag
# 11734.jpg predicted as Persian cat
# 11735.jpg predicted as nematode
# 11736.jpg predicted as electric ray
# 11737.jpg predicted as Egyptian cat
# 11738.jpg predicted as tub
# 11739.jpg predicted as lynx
# 1174.jpg predicted as Egyptian cat
# 11740.jpg predicted as lynx
# 11741.jpg predicted as Egyptian cat
# 11742.jpg predicted as window screen
# 11743.jpg predicted as mosquito net
# 11744.jpg predicted as Egyptian cat
# 11745.jpg predicted as tabby
# 11746.jpg predicted as dishwasher
# 11747.jpg predicted as Egyptian cat
# 11748.jpg predicted as photocopier
# 11749.jpg predicted as bassinet
# 1175.jpg predicted as plastic bag
# 11750.jpg predicted as tabby
# 11751.jpg predicted as paper towel
# 11752.jpg predicted as Egyptian cat
# 11753.jpg predicted as Siamese cat
# 11754.jpg predicted as Egyptian cat
# 11755.jpg predicted as Persian cat
# 11756.jpg predicted as Egyptian cat
# 11757.jpg predicted as Egyptian cat
# 11758.jpg predicted as Eskimo dog
# 11759.jpg predicted as Chihuahua
# 1176.jpg predicted as lynx
# 11760.jpg predicted as lynx
# 11761.jpg predicted as tabby
# 11762.jpg predicted as tabby
# 11763.jpg predicted as Egyptian cat
# 11764.jpg predicted as plastic bag
# 11765.jpg predicted as Arctic fox
# 11766.jpg predicted as Persian cat
# 11767.jpg predicted as Persian cat
# 11768.jpg predicted as bassinet
# 11769.jpg predicted as tiger cat
# 1177.jpg predicted as Persian cat
# 11770.jpg predicted as Egyptian cat
# 11771.jpg predicted as Persian cat
# 11772.jpg predicted as Egyptian cat
# 11773.jpg predicted as bucket
# 11774.jpg predicted as paper towel
# 11775.jpg predicted as tub
# 11776.jpg predicted as tabby
# 11777.jpg predicted as washbasin
# 11778.jpg predicted as stingray
# 11779.jpg predicted as mosquito net
# 1178.jpg predicted as shower curtain
# 11780.jpg predicted as mosquito net
# 11781.jpg predicted as plastic bag
# 11782.jpg predicted as schipperke
# 11783.jpg predicted as Angora
# 11784.jpg predicted as tub
# 11785.jpg predicted as Egyptian cat
# 11786.jpg predicted as paper towel
# 11787.jpg predicted as hamster
# 11788.jpg predicted as Arctic fox
# 11789.jpg predicted as paper towel
# 1179.jpg predicted as Persian cat
# 11790.jpg predicted as Angora
# 11791.jpg predicted as plastic bag
# 11792.jpg predicted as diaper
# 11793.jpg predicted as vase
# 11794.jpg predicted as plastic bag
# 11795.jpg predicted as Persian cat
# 11796.jpg predicted as Egyptian cat
# 11797.jpg predicted as tabby
# 11798.jpg predicted as tabby
# 11799.jpg predicted as hamper
# 118.jpg predicted as Persian cat
# 1180.jpg predicted as tub
# 11800.jpg predicted as shower curtain
# 11801.jpg predicted as Persian cat
# 11802.jpg predicted as tabby
# 11803.jpg predicted as Persian cat
# 11804.jpg predicted as mosquito net
# 11805.jpg predicted as miniature pinscher
# 11806.jpg predicted as Egyptian cat
# 11807.jpg predicted as Siamese cat
# 11808.jpg predicted as tub
# 11809.jpg predicted as Egyptian cat
# 1181.jpg predicted as Egyptian cat
# 11810.jpg predicted as plastic bag
# 11811.jpg predicted as shower curtain
# 11812.jpg predicted as mosquito net
# 11813.jpg predicted as hamster
# 11814.jpg predicted as Persian cat
# 11815.jpg predicted as Siamese cat
# 11816.jpg predicted as tub
# 11817.jpg predicted as tiger cat
# 11818.jpg predicted as Angora
# 11819.jpg predicted as shower curtain
# 1182.jpg predicted as Saint Bernard
# 11820.jpg predicted as tiger cat
# 11821.jpg predicted as Persian cat
# 11822.jpg predicted as Boston bull
# 11823.jpg predicted as tricycle
# 11824.jpg predicted as Egyptian cat
# 11825.jpg predicted as Egyptian cat
# 11826.jpg predicted as groenendael
# 11827.jpg predicted as Egyptian cat
# 11828.jpg predicted as Egyptian cat
# 11829.jpg predicted as Persian cat
# 1183.jpg predicted as Egyptian cat
# 11830.jpg predicted as Egyptian cat
# 11831.jpg predicted as Egyptian cat
# 11832.jpg predicted as Samoyed
# 11833.jpg predicted as Angora
# 11834.jpg predicted as Samoyed
# 11835.jpg predicted as bathtub
# 11836.jpg predicted as plastic bag
# 11837.jpg predicted as Egyptian cat
# 11838.jpg predicted as Angora
# 11839.jpg predicted as shower curtain
# 1184.jpg predicted as toilet tissue
# 11840.jpg predicted as weasel
# 11841.jpg predicted as Persian cat
# 11842.jpg predicted as carton
# 11843.jpg predicted as tiger cat
# 11844.jpg predicted as oxygen mask
# 11845.jpg predicted as Arctic fox
# 11846.jpg predicted as toilet tissue
# 11847.jpg predicted as Kerry blue terrier
# 11848.jpg predicted as Persian cat
# 11849.jpg predicted as Egyptian cat
# 1185.jpg predicted as Persian cat
# 11850.jpg predicted as Egyptian cat
# 11851.jpg predicted as electric ray
# 11852.jpg predicted as tiger cat
# 11853.jpg predicted as shower curtain
# 11854.jpg predicted as mosquito net
# 11855.jpg predicted as Persian cat
# 11856.jpg predicted as shower curtain
# 11857.jpg predicted as lynx
# 11858.jpg predicted as Persian cat
# 11859.jpg predicted as plastic bag
# 1186.jpg predicted as plastic bag
# 11860.jpg predicted as Angora
# 11861.jpg predicted as bow tie
# 11862.jpg predicted as lynx
# 11863.jpg predicted as Egyptian cat
# 11864.jpg predicted as Egyptian cat
# 11865.jpg predicted as Siberian husky
# 11866.jpg predicted as cradle
# 11867.jpg predicted as Arctic fox
# 11868.jpg predicted as toilet seat
# 11869.jpg predicted as Egyptian cat
# 1187.jpg predicted as Egyptian cat
# 11870.jpg predicted as barn spider
# 11871.jpg predicted as plastic bag
# 11872.jpg predicted as Egyptian cat
# 11873.jpg predicted as tiger cat
# 11874.jpg is a black and white image
# 11875.jpg predicted as Egyptian cat
# 11876.jpg predicted as Egyptian cat
# 11877.jpg predicted as Egyptian cat
# 11878.jpg predicted as weasel
# 11879.jpg predicted as bathtub
# 1188.jpg predicted as bow tie
# 11880.jpg predicted as Eskimo dog
# 11881.jpg predicted as piggy bank
# 11882.jpg predicted as toilet seat
# 11883.jpg predicted as malamute
# 11884.jpg predicted as Egyptian cat
# 11885.jpg predicted as weasel
# 11886.jpg predicted as Persian cat
# 11887.jpg predicted as Egyptian cat
# 11888.jpg predicted as tub
# 11889.jpg predicted as Persian cat
# 1189.jpg predicted as bassinet
# 11890.jpg predicted as window screen
# 11891.jpg predicted as Siamese cat
# 11892.jpg predicted as Samoyed
# 11893.jpg predicted as Scotch terrier
# 11894.jpg predicted as tiger cat
# 11895.jpg predicted as toilet tissue
# 11896.jpg predicted as plastic bag
# 11897.jpg predicted as Persian cat
# 11898.jpg predicted as tiger cat
# 11899.jpg predicted as Egyptian cat
# 119.jpg predicted as tiger cat
# 1190.jpg predicted as lynx
# 11900.jpg predicted as Egyptian cat
# 11901.jpg predicted as plastic bag
# 11902.jpg predicted as Egyptian cat
# 11903.jpg predicted as Angora
# 11904.jpg predicted as Egyptian cat
# 11905.jpg predicted as tabby
# 11906.jpg predicted as Persian cat
# 11907.jpg predicted as shower curtain
# 11908.jpg predicted as Egyptian cat
# 11909.jpg predicted as plastic bag
# 1191.jpg predicted as Persian cat
# 11910.jpg predicted as bassinet
# 11911.jpg predicted as Persian cat
# 11912.jpg predicted as Siamese cat
# 11913.jpg predicted as Egyptian cat
# 11914.jpg predicted as bathtub
# 11915.jpg predicted as window screen
# 11916.jpg predicted as Egyptian cat
# 11917.jpg predicted as hamster
# 11918.jpg predicted as Egyptian cat
# 11919.jpg predicted as tub
# 1192.jpg predicted as handkerchief
# 11920.jpg predicted as Egyptian cat
# 11921.jpg predicted as bib
# 11922.jpg predicted as paper towel
# 11923.jpg predicted as plastic bag
# 11924.jpg predicted as lynx
# 11925.jpg predicted as Persian cat
# 11926.jpg predicted as Siamese cat
# 11927.jpg predicted as Persian cat
# 11928.jpg predicted as Egyptian cat
# 11929.jpg predicted as schipperke
# 1193.jpg predicted as Ibizan hound
# 11930.jpg predicted as plastic bag
# 11931.jpg predicted as Persian cat
# 11932.jpg predicted as bathtub
# 11933.jpg predicted as Egyptian cat
# 11934.jpg predicted as Egyptian cat
# 11935.jpg is a black and white image
# 11936.jpg predicted as Persian cat
# 11937.jpg predicted as Pembroke
# 11938.jpg predicted as feather boa
# 11939.jpg predicted as Persian cat
# 1194.jpg predicted as Egyptian cat
# 11940.jpg predicted as bathtub
# 11941.jpg predicted as Greater Swiss Mountain dog
# 11942.jpg predicted as Egyptian cat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 40
#      38 if input_tensor.size()[1] == 3:
#      39     with torch.no_grad():
# ---> 40         output_tensor = model(input_tensor)
#      41     prediction = weights.meta["categories"][output_tensor.argmax().item()]
#      42     print(f'{image_file} predicted as {prediction}')
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:276, in ResNet._forward_impl(self, x)
#     274 x = self.layer2(x)
#     275 x = self.layer3(x)
# --> 276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#     279 x = torch.flatten(x, 1)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:92, in BasicBlock.forward(self, x)
#      89 def forward(self, x: Tensor) -> Tensor:
#      90     identity = x
# ---> 92     out = self.conv1(x)
#      93     out = self.bn1(out)
#      94     out = self.relu(out)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
